# %% [markdown]
# # Household Electric Power Consumption
#
# Method used: XGBoost with rolling lags, preprocessing and window shifting.
#
# ### By Pratham Shah (B.Tech CSE, 240905614, 2028) for the Cryptonite Research Taskphase

# %% [markdown]
# ## Imports and Loading the Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
df = df.copy()
# Out:
# /tmp/ipykernel_90610/199733144.py:8: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
# /tmp/ipykernel_90610/199733144.py:8: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
# /tmp/ipykernel_90610/199733144.py:8: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])

# %% [markdown]
# # EDA

# %%
print("DATA INFORMATION:")
print(df.info())
print("\n\nDATA DESCRIPTION")
print(df.describe())
# Out:
# DATA INFORMATION:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   date_time              datetime64[ns]
#  1   Global_active_power    float64
#  2   Global_reactive_power  float64
#  3   Voltage                float64
#  4   Global_intensity       float64
#  5   Sub_metering_1         float64
#  6   Sub_metering_2         float64
#  7   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 126.7 MB
# None
#
#
# DATA DESCRIPTION
#                            date_time  Global_active_power  \
# count                        2075259         2.049280e+06
# mean   2008-12-06 07:12:59.999994112         1.091615e+00
# min              2006-12-16 17:24:00         7.600000e-02
# 25%              2007-12-12 00:18:30         3.080000e-01
# 50%              2008-12-06 07:13:00         6.020000e-01
# 75%              2009-12-01 14:07:30         1.528000e+00
# max              2010-11-26 21:02:00         1.112200e+01
# std                              NaN         1.057294e+00
#
#        Global_reactive_power       Voltage  Global_intensity  Sub_metering_1  \
# count           2.049280e+06  2.049280e+06      2.049280e+06    2.049280e+06
# mean            1.237145e-01  2.408399e+02      4.627759e+00    1.121923e+00
# min             0.000000e+00  2.232000e+02      2.000000e-01    0.000000e+00
# 25%             4.800000e-02  2.389900e+02      1.400000e+00    0.000000e+00
# 50%             1.000000e-01  2.410100e+02      2.600000e+00    0.000000e+00
# 75%             1.940000e-01  2.428900e+02      6.400000e+00    0.000000e+00
# max             1.390000e+00  2.541500e+02      4.840000e+01    8.800000e+01
# std             1.127220e-01  3.239987e+00      4.444396e+00    6.153031e+00
#
#        Sub_metering_2  Sub_metering_3
# count    2.049280e+06    2.049280e+06
# mean     1.298520e+00    6.458447e+00
# min      0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00
# 50%      0.000000e+00    1.000000e+00
# 75%      1.000000e+00    1.700000e+01
# max      8.000000e+01    3.100000e+01
# std      5.822026e+00    8.437154e+00

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Global_active_power'], label='Global Active Power')
plt.title('Global Active Power Over Time')
plt.ylabel('Power (kilowatts)')
plt.xlabel('Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
df_temp = df.copy()
hourly_avg = df_temp.groupby(df_temp["date_time"].dt.hour)['Global_active_power'].mean()

plt.figure(figsize=(12, 4))
hourly_avg.plot(kind='bar')
plt.title('Average Power Usage by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Avg Power (kW)')
plt.grid(True)
plt.show()

# %%
df_temp['day_name'] = df_temp["date_time"].dt.day_name()

plt.figure(figsize=(10, 5))
sns.boxplot(x='day_name', y='Global_active_power', data=df_temp)
plt.xlabel("Day")
plt.ylabel("Power (kW)")
plt.title('Power Usage by Day of Week')
plt.xticks(rotation=45)
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt

df_temp.set_index('date_time', inplace=True)
df_daily = df_temp['Global_active_power'].resample('D').mean()

plt.figure(figsize=(10, 4))
autocorrelation_plot(df_daily.dropna())
plt.title('Daily Autocorrelation')
plt.xlabel('Lag (days)')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Feature Engineering
#
# Rolling means of the past hour and lags of many intervals are introduced to allow the XGBoost model to regress more time-contextually.

# %%
df['year'] = df['date_time'].dt.year
df['quarter'] = df['date_time'].dt.quarter
df['month'] = df['date_time'].dt.month
df['day'] = df['date_time'].dt.day
df['hour_of_day'] = df['date_time'].dt.hour #creating new columns to better capture time dependencies
df['is_weekend'] = df['date_time'].dt.dayofweek >= 5
df['is_weekend'] = df['is_weekend'].astype(int)  #weekend : 1, weekday : 0. idea is that weekend signifies greater consumption

# Lag features
for lag in [1, 5, 30, 60, 1440]:
    df[f'lag_{lag}_min'] = df['Global_active_power'].shift(lag)

# Rolling statistics
df['rolling_mean_60'] = df['Global_active_power'].rolling(window=60).mean()
df['rolling_std_60'] = df['Global_active_power'].rolling(window=60).std()
    
df.sort_values('date_time', inplace=True, ascending=True)
df = df.reset_index(drop=True)

df.dropna(inplace=True) #drop all null/nan values introduced by rolling lag and within the dataset

df
# Out:
#                   date_time  Global_active_power  Global_reactive_power  \
# 1440    2006-12-17 17:24:00                3.390                  0.170
# 1441    2006-12-17 17:25:00                3.360                  0.164
# 1442    2006-12-17 17:26:00                3.400                  0.162
# 1443    2006-12-17 17:27:00                3.396                  0.164
# 1444    2006-12-17 17:28:00                3.282                  0.100
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 1440      232.65              14.6             0.0             0.0
# 1441      231.20              14.4             0.0             0.0
# 1442      232.86              14.6             0.0             0.0
# 1443      232.89              14.6             0.0             0.0
# 1444      232.33              14.0             0.0             0.0
# ...          ...               ...             ...             ...
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3  year  quarter  ...  day  hour_of_day  is_weekend  \
# 1440               17.0  2006        4  ...   17           17           1
# 1441               16.0  2006        4  ...   17           17           1
# 1442               17.0  2006        4  ...   17           17           1
# 1443               17.0  2006        4  ...   17           17           1
# 1444               16.0  2006        4  ...   17           17           1
# ...                 ...   ...      ...  ...  ...          ...         ...
# 2075254             0.0  2010        4  ...   26           20           0
# 2075255             0.0  2010        4  ...   26           20           0
# 2075256             0.0  2010        4  ...   26           21           0
# 2075257             0.0  2010        4  ...   26           21           0
# 2075258             0.0  2010        4  ...   26           21           0
#
#          lag_1_min  lag_5_min  lag_30_min  lag_60_min  lag_1440_min  \
# 1440         3.238      3.808       3.328       4.864         4.216
# 1441         3.390      3.580       3.316       4.868         5.360
# 1442         3.360      3.370       3.390       4.876         5.374
# 1443         3.400      3.130       3.418       4.810         5.388
# 1444         3.396      3.238       3.384       4.790         3.666
# ...            ...        ...         ...         ...           ...
# 2075254      0.946      0.944       0.982       1.526         1.522
# 2075255      0.946      0.946       0.958       1.524         1.518
# 2075256      0.944      0.946       0.980       1.456         1.512
# 2075257      0.938      0.942       0.982       1.554         1.508
# 2075258      0.934      0.946       0.982       1.596         1.502
#
#          rolling_mean_60  rolling_std_60
# 1440            3.527967        0.671762
# 1441            3.502833        0.648586
# 1442            3.478233        0.623112
# 1443            3.454667        0.598129
# 1444            3.429533        0.572188
# ...                  ...             ...
# 2075254         1.173367        0.312391
# 2075255         1.163700        0.310324
# 2075256         1.155067        0.309258
# 2075257         1.144733        0.306044
# 2075258         1.133667        0.301420
#
# [2034118 rows x 21 columns]

# %%
df.drop(["Global_intensity", "date_time"], axis=1, inplace=True)

print('Number of rows and columns:', df.shape)
# Out:
# Number of rows and columns: (2034118, 19)

# %% [markdown]
# ## Preparation for the Model

# %%
target_col = 'Global_active_power'
features = df.drop(columns=[target_col])
target = df[target_col] #split target and x

split_index = int(len(df) * 0.8) #0.8 split of train and test data

X_train_raw, X_test_raw = features[:split_index], features[split_index:]
y_train_raw, y_test_raw = target[:split_index], target[split_index:]

feature_scaler = StandardScaler()
X_train = pd.DataFrame(
    feature_scaler.fit_transform(X_train_raw),
    columns=X_train_raw.columns,
    index=X_train_raw.index
)
X_test = pd.DataFrame(
    feature_scaler.transform(X_test_raw),
    columns=X_test_raw.columns,
    index=X_test_raw.index
)

target_scaler = StandardScaler() #different scaler for target - needed to invert
y_train = target_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_test = target_scaler.transform(y_test_raw.values.reshape(-1, 1))

# %% [markdown]
# ## The Model

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=1300, learning_rate=0.14)

eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train,
          eval_set=eval_set,
          verbose=2)

results = model.evals_result()

epochs = len(results['validation_0']['rmse'])
x_axis = range(epochs)

plt.figure(figsize=(10, 5))
plt.plot(x_axis, results['validation_0']['rmse'], label='Train RMSE')
plt.plot(x_axis, results['validation_1']['rmse'], label='Validation RMSE')
plt.title('XGBoost Training vs Validation RMSE')
plt.xlabel('Boosting Round')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [0]	validation_0-rmse:0.86813	validation_1-rmse:0.71447
# [2]	validation_0-rmse:0.65996	validation_1-rmse:0.53845
# [4]	validation_0-rmse:0.51064	validation_1-rmse:0.41295
# [6]	validation_0-rmse:0.40514	validation_1-rmse:0.32449
# [8]	validation_0-rmse:0.33221	validation_1-rmse:0.26271
# [10]	validation_0-rmse:0.28306	validation_1-rmse:0.22184
# [12]	validation_0-rmse:0.25116	validation_1-rmse:0.19613
# [14]	validation_0-rmse:0.23098	validation_1-rmse:0.18004
# [16]	validation_0-rmse:0.21803	validation_1-rmse:0.17006
# [18]	validation_0-rmse:0.20957	validation_1-rmse:0.16363
# [20]	validation_0-rmse:0.20326	validation_1-rmse:0.15921
# [22]	validation_0-rmse:0.19908	validation_1-rmse:0.15647
# [24]	validation_0-rmse:0.19609	validation_1-rmse:0.15481
# [26]	validation_0-rmse:0.19356	validation_1-rmse:0.15338
# [28]	validation_0-rmse:0.19157	validation_1-rmse:0.15210
# [30]	validation_0-rmse:0.18986	validation_1-rmse:0.15093
# [32]	validation_0-rmse:0.18860	validation_1-rmse:0.15036
# [34]	validation_0-rmse:0.18750	validation_1-rmse:0.14972
# [36]	validation_0-rmse:0.18640	validation_1-rmse:0.14888
# [38]	validation_0-rmse:0.18551	validation_1-rmse:0.14845
# [40]	validation_0-rmse:0.18461	validation_1-rmse:0.14778
# [42]	validation_0-rmse:0.18388	validation_1-rmse:0.14737
# [44]	validation_0-rmse:0.18313	validation_1-rmse:0.14711
# [46]	validation_0-rmse:0.18253	validation_1-rmse:0.14689
# [48]	validation_0-rmse:0.18199	validation_1-rmse:0.14656
# [50]	validation_0-rmse:0.18145	validation_1-rmse:0.14647
# [52]	validation_0-rmse:0.18089	validation_1-rmse:0.14640
# [54]	validation_0-rmse:0.18037	validation_1-rmse:0.14609
# [56]	validation_0-rmse:0.18005	validation_1-rmse:0.14594
# [58]	validation_0-rmse:0.17930	validation_1-rmse:0.14558
# [60]	validation_0-rmse:0.17895	validation_1-rmse:0.14544
# [62]	validation_0-rmse:0.17847	validation_1-rmse:0.14523
# [64]	validation_0-rmse:0.17811	validation_1-rmse:0.14509
# [66]	validation_0-rmse:0.17766	validation_1-rmse:0.14472
# [68]	validation_0-rmse:0.17730	validation_1-rmse:0.14462
# [70]	validation_0-rmse:0.17699	validation_1-rmse:0.14450
# [72]	validation_0-rmse:0.17659	validation_1-rmse:0.14432
# [74]	validation_0-rmse:0.17630	validation_1-rmse:0.14422
# [76]	validation_0-rmse:0.17588	validation_1-rmse:0.14392
# [78]	validation_0-rmse:0.17569	validation_1-rmse:0.14384
# [80]	validation_0-rmse:0.17549	validation_1-rmse:0.14379
# [82]	validation_0-rmse:0.17528	validation_1-rmse:0.14372
# [84]	validation_0-rmse:0.17491	validation_1-rmse:0.14358
# [86]	validation_0-rmse:0.17470	validation_1-rmse:0.14346
# [88]	validation_0-rmse:0.17422	validation_1-rmse:0.14328
# [90]	validation_0-rmse:0.17401	validation_1-rmse:0.14326
# [92]	validation_0-rmse:0.17372	validation_1-rmse:0.14307
# [94]	validation_0-rmse:0.17342	validation_1-rmse:0.14292
# [96]	validation_0-rmse:0.17318	validation_1-rmse:0.14283
# [98]	validation_0-rmse:0.17294	validation_1-rmse:0.14274
# [100]	validation_0-rmse:0.17249	validation_1-rmse:0.14261
# [102]	validation_0-rmse:0.17218	validation_1-rmse:0.14238
# [104]	validation_0-rmse:0.17200	validation_1-rmse:0.14237
# [106]	validation_0-rmse:0.17155	validation_1-rmse:0.14220
# [108]	validation_0-rmse:0.17137	validation_1-rmse:0.14215
# [110]	validation_0-rmse:0.17127	validation_1-rmse:0.14214
# [112]	validation_0-rmse:0.17101	validation_1-rmse:0.14205
# [114]	validation_0-rmse:0.17077	validation_1-rmse:0.14196
# [116]	validation_0-rmse:0.17047	validation_1-rmse:0.14189
# [118]	validation_0-rmse:0.17025	validation_1-rmse:0.14183
# [120]	validation_0-rmse:0.17012	validation_1-rmse:0.14176
# [122]	validation_0-rmse:0.16990	validation_1-rmse:0.14167
# [124]	validation_0-rmse:0.16969	validation_1-rmse:0.14155
# [126]	validation_0-rmse:0.16946	validation_1-rmse:0.14152
# [128]	validation_0-rmse:0.16938	validation_1-rmse:0.14152
# [130]	validation_0-rmse:0.16903	validation_1-rmse:0.14135
# [132]	validation_0-rmse:0.16879	validation_1-rmse:0.14119
# [134]	validation_0-rmse:0.16870	validation_1-rmse:0.14120
# [136]	validation_0-rmse:0.16850	validation_1-rmse:0.14112
# [138]	validation_0-rmse:0.16838	validation_1-rmse:0.14108
# [140]	validation_0-rmse:0.16819	validation_1-rmse:0.14094
# [142]	validation_0-rmse:0.16811	validation_1-rmse:0.14093
# [144]	validation_0-rmse:0.16789	validation_1-rmse:0.14091
# [146]	validation_0-rmse:0.16768	validation_1-rmse:0.14082
# [148]	validation_0-rmse:0.16751	validation_1-rmse:0.14074
# [150]	validation_0-rmse:0.16742	validation_1-rmse:0.14073
# [152]	validation_0-rmse:0.16721	validation_1-rmse:0.14059
# [154]	validation_0-rmse:0.16703	validation_1-rmse:0.14054
# [156]	validation_0-rmse:0.16692	validation_1-rmse:0.14049
# [158]	validation_0-rmse:0.16681	validation_1-rmse:0.14046
# [160]	validation_0-rmse:0.16664	validation_1-rmse:0.14040
# [162]	validation_0-rmse:0.16648	validation_1-rmse:0.14023
# [164]	validation_0-rmse:0.16623	validation_1-rmse:0.14011
# [166]	validation_0-rmse:0.16613	validation_1-rmse:0.14014
# [168]	validation_0-rmse:0.16595	validation_1-rmse:0.14002
# [170]	validation_0-rmse:0.16587	validation_1-rmse:0.14000
# [172]	validation_0-rmse:0.16566	validation_1-rmse:0.13995
# [174]	validation_0-rmse:0.16558	validation_1-rmse:0.13993
# [176]	validation_0-rmse:0.16545	validation_1-rmse:0.13989
# [178]	validation_0-rmse:0.16531	validation_1-rmse:0.13979
# [180]	validation_0-rmse:0.16520	validation_1-rmse:0.13976
# [182]	validation_0-rmse:0.16508	validation_1-rmse:0.13965
# [184]	validation_0-rmse:0.16488	validation_1-rmse:0.13963
# [186]	validation_0-rmse:0.16480	validation_1-rmse:0.13964
# [188]	validation_0-rmse:0.16471	validation_1-rmse:0.13960
# [190]	validation_0-rmse:0.16450	validation_1-rmse:0.13958
# [192]	validation_0-rmse:0.16436	validation_1-rmse:0.13955
# [194]	validation_0-rmse:0.16428	validation_1-rmse:0.13956
# [196]	validation_0-rmse:0.16420	validation_1-rmse:0.13959
# [198]	validation_0-rmse:0.16394	validation_1-rmse:0.13948
# [200]	validation_0-rmse:0.16385	validation_1-rmse:0.13948
# [202]	validation_0-rmse:0.16364	validation_1-rmse:0.13944
# [204]	validation_0-rmse:0.16353	validation_1-rmse:0.13944
# [206]	validation_0-rmse:0.16343	validation_1-rmse:0.13942
# [208]	validation_0-rmse:0.16330	validation_1-rmse:0.13934
# [210]	validation_0-rmse:0.16315	validation_1-rmse:0.13927
# [212]	validation_0-rmse:0.16304	validation_1-rmse:0.13920
# [214]	validation_0-rmse:0.16292	validation_1-rmse:0.13919
# [216]	validation_0-rmse:0.16287	validation_1-rmse:0.13920
# [218]	validation_0-rmse:0.16273	validation_1-rmse:0.13918
# [220]	validation_0-rmse:0.16259	validation_1-rmse:0.13911
# [222]	validation_0-rmse:0.16255	validation_1-rmse:0.13913
# [224]	validation_0-rmse:0.16249	validation_1-rmse:0.13912
# [226]	validation_0-rmse:0.16238	validation_1-rmse:0.13911
# [228]	validation_0-rmse:0.16225	validation_1-rmse:0.13908
# [230]	validation_0-rmse:0.16218	validation_1-rmse:0.13908
# [232]	validation_0-rmse:0.16206	validation_1-rmse:0.13904
# [234]	validation_0-rmse:0.16194	validation_1-rmse:0.13901
# [236]	validation_0-rmse:0.16184	validation_1-rmse:0.13901
# [238]	validation_0-rmse:0.16177	validation_1-rmse:0.13905
# [240]	validation_0-rmse:0.16168	validation_1-rmse:0.13902
# [242]	validation_0-rmse:0.16156	validation_1-rmse:0.13901
# [244]	validation_0-rmse:0.16143	validation_1-rmse:0.13900
# [246]	validation_0-rmse:0.16133	validation_1-rmse:0.13899
# [248]	validation_0-rmse:0.16114	validation_1-rmse:0.13893
# [250]	validation_0-rmse:0.16098	validation_1-rmse:0.13887
# [252]	validation_0-rmse:0.16088	validation_1-rmse:0.13886
# [254]	validation_0-rmse:0.16081	validation_1-rmse:0.13886
# [256]	validation_0-rmse:0.16070	validation_1-rmse:0.13885
# [258]	validation_0-rmse:0.16064	validation_1-rmse:0.13884
# [260]	validation_0-rmse:0.16052	validation_1-rmse:0.13885
# [262]	validation_0-rmse:0.16043	validation_1-rmse:0.13885
# [264]	validation_0-rmse:0.16038	validation_1-rmse:0.13884
# [266]	validation_0-rmse:0.16018	validation_1-rmse:0.13876
# [268]	validation_0-rmse:0.16007	validation_1-rmse:0.13872
# [270]	validation_0-rmse:0.15999	validation_1-rmse:0.13867
# [272]	validation_0-rmse:0.15991	validation_1-rmse:0.13863
# [274]	validation_0-rmse:0.15988	validation_1-rmse:0.13866
# [276]	validation_0-rmse:0.15981	validation_1-rmse:0.13867
# [278]	validation_0-rmse:0.15973	validation_1-rmse:0.13865
# [280]	validation_0-rmse:0.15962	validation_1-rmse:0.13864
# [282]	validation_0-rmse:0.15953	validation_1-rmse:0.13872
# [284]	validation_0-rmse:0.15947	validation_1-rmse:0.13871
# [286]	validation_0-rmse:0.15940	validation_1-rmse:0.13866
# [288]	validation_0-rmse:0.15934	validation_1-rmse:0.13864
# [290]	validation_0-rmse:0.15928	validation_1-rmse:0.13866
# [292]	validation_0-rmse:0.15920	validation_1-rmse:0.13866
# [294]	validation_0-rmse:0.15904	validation_1-rmse:0.13858
# [296]	validation_0-rmse:0.15893	validation_1-rmse:0.13855
# [298]	validation_0-rmse:0.15885	validation_1-rmse:0.13869
# [300]	validation_0-rmse:0.15875	validation_1-rmse:0.13871
# [302]	validation_0-rmse:0.15860	validation_1-rmse:0.13866
# [304]	validation_0-rmse:0.15854	validation_1-rmse:0.13864
# [306]	validation_0-rmse:0.15848	validation_1-rmse:0.13869
# [308]	validation_0-rmse:0.15839	validation_1-rmse:0.13867
# [310]	validation_0-rmse:0.15830	validation_1-rmse:0.13864
# [312]	validation_0-rmse:0.15826	validation_1-rmse:0.13864
# [314]	validation_0-rmse:0.15817	validation_1-rmse:0.13859
# [316]	validation_0-rmse:0.15811	validation_1-rmse:0.13856
# [318]	validation_0-rmse:0.15805	validation_1-rmse:0.13856
# [320]	validation_0-rmse:0.15800	validation_1-rmse:0.13857
# [322]	validation_0-rmse:0.15793	validation_1-rmse:0.13849
# [324]	validation_0-rmse:0.15788	validation_1-rmse:0.13850
# [326]	validation_0-rmse:0.15785	validation_1-rmse:0.13848
# [328]	validation_0-rmse:0.15780	validation_1-rmse:0.13849
# [330]	validation_0-rmse:0.15774	validation_1-rmse:0.13848
# [332]	validation_0-rmse:0.15766	validation_1-rmse:0.13846
# [334]	validation_0-rmse:0.15753	validation_1-rmse:0.13841
# [336]	validation_0-rmse:0.15745	validation_1-rmse:0.13841
# [338]	validation_0-rmse:0.15739	validation_1-rmse:0.13851
# [340]	validation_0-rmse:0.15733	validation_1-rmse:0.13852
# [342]	validation_0-rmse:0.15725	validation_1-rmse:0.13849
# [344]	validation_0-rmse:0.15719	validation_1-rmse:0.13848
# [346]	validation_0-rmse:0.15717	validation_1-rmse:0.13852
# [348]	validation_0-rmse:0.15711	validation_1-rmse:0.13850
# [350]	validation_0-rmse:0.15698	validation_1-rmse:0.13845
# [352]	validation_0-rmse:0.15689	validation_1-rmse:0.13850
# [354]	validation_0-rmse:0.15679	validation_1-rmse:0.13851
# [356]	validation_0-rmse:0.15674	validation_1-rmse:0.13858
# [358]	validation_0-rmse:0.15672	validation_1-rmse:0.13856
# [360]	validation_0-rmse:0.15666	validation_1-rmse:0.13857
# [362]	validation_0-rmse:0.15656	validation_1-rmse:0.13854
# [364]	validation_0-rmse:0.15644	validation_1-rmse:0.13855
# [366]	validation_0-rmse:0.15640	validation_1-rmse:0.13855
# [368]	validation_0-rmse:0.15631	validation_1-rmse:0.13854
# [370]	validation_0-rmse:0.15624	validation_1-rmse:0.13853
# [372]	validation_0-rmse:0.15617	validation_1-rmse:0.13849
# [374]	validation_0-rmse:0.15614	validation_1-rmse:0.13847
# [376]	validation_0-rmse:0.15604	validation_1-rmse:0.13848
# [378]	validation_0-rmse:0.15596	validation_1-rmse:0.13846
# [380]	validation_0-rmse:0.15582	validation_1-rmse:0.13841
# [382]	validation_0-rmse:0.15576	validation_1-rmse:0.13840
# [384]	validation_0-rmse:0.15567	validation_1-rmse:0.13837
# [386]	validation_0-rmse:0.15562	validation_1-rmse:0.13837
# [388]	validation_0-rmse:0.15557	validation_1-rmse:0.13837
# [390]	validation_0-rmse:0.15553	validation_1-rmse:0.13837
# [392]	validation_0-rmse:0.15547	validation_1-rmse:0.13838
# [394]	validation_0-rmse:0.15543	validation_1-rmse:0.13837
# [396]	validation_0-rmse:0.15533	validation_1-rmse:0.13834
# [398]	validation_0-rmse:0.15525	validation_1-rmse:0.13836
# [400]	validation_0-rmse:0.15521	validation_1-rmse:0.13832
# [402]	validation_0-rmse:0.15513	validation_1-rmse:0.13832
# [404]	validation_0-rmse:0.15508	validation_1-rmse:0.13838
# [406]	validation_0-rmse:0.15505	validation_1-rmse:0.13838
# [408]	validation_0-rmse:0.15503	validation_1-rmse:0.13838
# [410]	validation_0-rmse:0.15499	validation_1-rmse:0.13838
# [412]	validation_0-rmse:0.15491	validation_1-rmse:0.13838
# [414]	validation_0-rmse:0.15482	validation_1-rmse:0.13840
# [416]	validation_0-rmse:0.15478	validation_1-rmse:0.13841
# [418]	validation_0-rmse:0.15472	validation_1-rmse:0.13840
# [420]	validation_0-rmse:0.15468	validation_1-rmse:0.13840
# [422]	validation_0-rmse:0.15464	validation_1-rmse:0.13839
# [424]	validation_0-rmse:0.15457	validation_1-rmse:0.13838
# [426]	validation_0-rmse:0.15454	validation_1-rmse:0.13839
# [428]	validation_0-rmse:0.15447	validation_1-rmse:0.13838
# [430]	validation_0-rmse:0.15442	validation_1-rmse:0.13838
# [432]	validation_0-rmse:0.15437	validation_1-rmse:0.13838
# [434]	validation_0-rmse:0.15430	validation_1-rmse:0.13836
# [436]	validation_0-rmse:0.15424	validation_1-rmse:0.13839
# [438]	validation_0-rmse:0.15417	validation_1-rmse:0.13837
# [440]	validation_0-rmse:0.15414	validation_1-rmse:0.13837
# [442]	validation_0-rmse:0.15412	validation_1-rmse:0.13837
# [444]	validation_0-rmse:0.15405	validation_1-rmse:0.13835
# [446]	validation_0-rmse:0.15398	validation_1-rmse:0.13829
# [448]	validation_0-rmse:0.15394	validation_1-rmse:0.13829
# [450]	validation_0-rmse:0.15387	validation_1-rmse:0.13828
# [452]	validation_0-rmse:0.15379	validation_1-rmse:0.13824
# [454]	validation_0-rmse:0.15372	validation_1-rmse:0.13821
# [456]	validation_0-rmse:0.15364	validation_1-rmse:0.13823
# [458]	validation_0-rmse:0.15358	validation_1-rmse:0.13823
# [460]	validation_0-rmse:0.15351	validation_1-rmse:0.13819
# [462]	validation_0-rmse:0.15345	validation_1-rmse:0.13817
# [464]	validation_0-rmse:0.15343	validation_1-rmse:0.13817
# [466]	validation_0-rmse:0.15341	validation_1-rmse:0.13817
# [468]	validation_0-rmse:0.15337	validation_1-rmse:0.13816
# [470]	validation_0-rmse:0.15329	validation_1-rmse:0.13813
# [472]	validation_0-rmse:0.15319	validation_1-rmse:0.13811
# [474]	validation_0-rmse:0.15311	validation_1-rmse:0.13811
# [476]	validation_0-rmse:0.15298	validation_1-rmse:0.13806
# [478]	validation_0-rmse:0.15289	validation_1-rmse:0.13805
# [480]	validation_0-rmse:0.15282	validation_1-rmse:0.13804
# [482]	validation_0-rmse:0.15278	validation_1-rmse:0.13803
# [484]	validation_0-rmse:0.15272	validation_1-rmse:0.13799
# [486]	validation_0-rmse:0.15267	validation_1-rmse:0.13798
# [488]	validation_0-rmse:0.15263	validation_1-rmse:0.13797
# [490]	validation_0-rmse:0.15260	validation_1-rmse:0.13798
# [492]	validation_0-rmse:0.15255	validation_1-rmse:0.13797
# [494]	validation_0-rmse:0.15248	validation_1-rmse:0.13798
# [496]	validation_0-rmse:0.15244	validation_1-rmse:0.13797
# [498]	validation_0-rmse:0.15240	validation_1-rmse:0.13797
# [500]	validation_0-rmse:0.15229	validation_1-rmse:0.13796
# [502]	validation_0-rmse:0.15226	validation_1-rmse:0.13795
# [504]	validation_0-rmse:0.15216	validation_1-rmse:0.13791
# [506]	validation_0-rmse:0.15209	validation_1-rmse:0.13784
# [508]	validation_0-rmse:0.15202	validation_1-rmse:0.13780
# [510]	validation_0-rmse:0.15194	validation_1-rmse:0.13781
# [512]	validation_0-rmse:0.15190	validation_1-rmse:0.13783
# [514]	validation_0-rmse:0.15187	validation_1-rmse:0.13783
# [516]	validation_0-rmse:0.15185	validation_1-rmse:0.13783
# [518]	validation_0-rmse:0.15179	validation_1-rmse:0.13782
# [520]	validation_0-rmse:0.15174	validation_1-rmse:0.13782
# [522]	validation_0-rmse:0.15167	validation_1-rmse:0.13778
# [524]	validation_0-rmse:0.15163	validation_1-rmse:0.13777
# [526]	validation_0-rmse:0.15158	validation_1-rmse:0.13778
# [528]	validation_0-rmse:0.15156	validation_1-rmse:0.13776
# [530]	validation_0-rmse:0.15151	validation_1-rmse:0.13777
# [532]	validation_0-rmse:0.15143	validation_1-rmse:0.13777
# [534]	validation_0-rmse:0.15139	validation_1-rmse:0.13777
# [536]	validation_0-rmse:0.15135	validation_1-rmse:0.13777
# [538]	validation_0-rmse:0.15129	validation_1-rmse:0.13781
# [540]	validation_0-rmse:0.15122	validation_1-rmse:0.13779
# [542]	validation_0-rmse:0.15118	validation_1-rmse:0.13779
# [544]	validation_0-rmse:0.15114	validation_1-rmse:0.13779
# [546]	validation_0-rmse:0.15112	validation_1-rmse:0.13778
# [548]	validation_0-rmse:0.15108	validation_1-rmse:0.13779
# [550]	validation_0-rmse:0.15104	validation_1-rmse:0.13778
# [552]	validation_0-rmse:0.15098	validation_1-rmse:0.13777
# [554]	validation_0-rmse:0.15093	validation_1-rmse:0.13773
# [556]	validation_0-rmse:0.15088	validation_1-rmse:0.13773
# [558]	validation_0-rmse:0.15083	validation_1-rmse:0.13775
# [560]	validation_0-rmse:0.15079	validation_1-rmse:0.13773
# [562]	validation_0-rmse:0.15069	validation_1-rmse:0.13772
# [564]	validation_0-rmse:0.15063	validation_1-rmse:0.13772
# [566]	validation_0-rmse:0.15057	validation_1-rmse:0.13771
# [568]	validation_0-rmse:0.15054	validation_1-rmse:0.13771
# [570]	validation_0-rmse:0.15052	validation_1-rmse:0.13771
# [572]	validation_0-rmse:0.15046	validation_1-rmse:0.13791
# [574]	validation_0-rmse:0.15042	validation_1-rmse:0.13790
# [576]	validation_0-rmse:0.15040	validation_1-rmse:0.13790
# [578]	validation_0-rmse:0.15038	validation_1-rmse:0.13790
# [580]	validation_0-rmse:0.15035	validation_1-rmse:0.13790
# [582]	validation_0-rmse:0.15029	validation_1-rmse:0.13789
# [584]	validation_0-rmse:0.15026	validation_1-rmse:0.13789
# [586]	validation_0-rmse:0.15020	validation_1-rmse:0.13788
# [588]	validation_0-rmse:0.15015	validation_1-rmse:0.13788
# [590]	validation_0-rmse:0.15012	validation_1-rmse:0.13784
# [592]	validation_0-rmse:0.15010	validation_1-rmse:0.13786
# [594]	validation_0-rmse:0.15008	validation_1-rmse:0.13789
# [596]	validation_0-rmse:0.15006	validation_1-rmse:0.13790
# [598]	validation_0-rmse:0.14999	validation_1-rmse:0.13789
# [600]	validation_0-rmse:0.14993	validation_1-rmse:0.13789
# [602]	validation_0-rmse:0.14987	validation_1-rmse:0.13790
# [604]	validation_0-rmse:0.14980	validation_1-rmse:0.13790
# [606]	validation_0-rmse:0.14970	validation_1-rmse:0.13789
# [608]	validation_0-rmse:0.14966	validation_1-rmse:0.13789
# [610]	validation_0-rmse:0.14960	validation_1-rmse:0.13788
# [612]	validation_0-rmse:0.14952	validation_1-rmse:0.13784
# [614]	validation_0-rmse:0.14947	validation_1-rmse:0.13796
# [616]	validation_0-rmse:0.14941	validation_1-rmse:0.13788
# [618]	validation_0-rmse:0.14935	validation_1-rmse:0.13788
# [620]	validation_0-rmse:0.14930	validation_1-rmse:0.13789
# [622]	validation_0-rmse:0.14928	validation_1-rmse:0.13789
# [624]	validation_0-rmse:0.14923	validation_1-rmse:0.13788
# [626]	validation_0-rmse:0.14921	validation_1-rmse:0.13786
# [628]	validation_0-rmse:0.14914	validation_1-rmse:0.13785
# [630]	validation_0-rmse:0.14910	validation_1-rmse:0.13785
# [632]	validation_0-rmse:0.14905	validation_1-rmse:0.13783
# [634]	validation_0-rmse:0.14903	validation_1-rmse:0.13784
# [636]	validation_0-rmse:0.14898	validation_1-rmse:0.13783
# [638]	validation_0-rmse:0.14892	validation_1-rmse:0.13782
# [640]	validation_0-rmse:0.14887	validation_1-rmse:0.13782
# [642]	validation_0-rmse:0.14881	validation_1-rmse:0.13782
# [644]	validation_0-rmse:0.14878	validation_1-rmse:0.13783
# [646]	validation_0-rmse:0.14874	validation_1-rmse:0.13782
# [648]	validation_0-rmse:0.14871	validation_1-rmse:0.13782
# [650]	validation_0-rmse:0.14865	validation_1-rmse:0.13783
# [652]	validation_0-rmse:0.14859	validation_1-rmse:0.13786
# [654]	validation_0-rmse:0.14857	validation_1-rmse:0.13785
# [656]	validation_0-rmse:0.14850	validation_1-rmse:0.13784
# [658]	validation_0-rmse:0.14845	validation_1-rmse:0.13783
# [660]	validation_0-rmse:0.14838	validation_1-rmse:0.13783
# [662]	validation_0-rmse:0.14833	validation_1-rmse:0.13782
# [664]	validation_0-rmse:0.14829	validation_1-rmse:0.13782
# [666]	validation_0-rmse:0.14826	validation_1-rmse:0.13784
# [668]	validation_0-rmse:0.14822	validation_1-rmse:0.13784
# [670]	validation_0-rmse:0.14820	validation_1-rmse:0.13784
# [672]	validation_0-rmse:0.14820	validation_1-rmse:0.13785
# [674]	validation_0-rmse:0.14814	validation_1-rmse:0.13785
# [676]	validation_0-rmse:0.14809	validation_1-rmse:0.13791
# [678]	validation_0-rmse:0.14803	validation_1-rmse:0.13790
# [680]	validation_0-rmse:0.14800	validation_1-rmse:0.13791
# [682]	validation_0-rmse:0.14798	validation_1-rmse:0.13790
# [684]	validation_0-rmse:0.14795	validation_1-rmse:0.13787
# [686]	validation_0-rmse:0.14786	validation_1-rmse:0.13783
# [688]	validation_0-rmse:0.14782	validation_1-rmse:0.13782
# [690]	validation_0-rmse:0.14778	validation_1-rmse:0.13776
# [692]	validation_0-rmse:0.14774	validation_1-rmse:0.13778
# [694]	validation_0-rmse:0.14770	validation_1-rmse:0.13783
# [696]	validation_0-rmse:0.14768	validation_1-rmse:0.13783
# [698]	validation_0-rmse:0.14763	validation_1-rmse:0.13781
# [700]	validation_0-rmse:0.14757	validation_1-rmse:0.13791
# [702]	validation_0-rmse:0.14753	validation_1-rmse:0.13792
# [704]	validation_0-rmse:0.14750	validation_1-rmse:0.13793
# [706]	validation_0-rmse:0.14746	validation_1-rmse:0.13793
# [708]	validation_0-rmse:0.14744	validation_1-rmse:0.13793
# [710]	validation_0-rmse:0.14740	validation_1-rmse:0.13793
# [712]	validation_0-rmse:0.14735	validation_1-rmse:0.13792
# [714]	validation_0-rmse:0.14731	validation_1-rmse:0.13792
# [716]	validation_0-rmse:0.14725	validation_1-rmse:0.13792
# [718]	validation_0-rmse:0.14722	validation_1-rmse:0.13792
# [720]	validation_0-rmse:0.14718	validation_1-rmse:0.13793
# [722]	validation_0-rmse:0.14715	validation_1-rmse:0.13792
# [724]	validation_0-rmse:0.14713	validation_1-rmse:0.13791
# [726]	validation_0-rmse:0.14711	validation_1-rmse:0.13791
# [728]	validation_0-rmse:0.14705	validation_1-rmse:0.13792
# [730]	validation_0-rmse:0.14701	validation_1-rmse:0.13791
# [732]	validation_0-rmse:0.14697	validation_1-rmse:0.13791
# [734]	validation_0-rmse:0.14690	validation_1-rmse:0.13792
# [736]	validation_0-rmse:0.14686	validation_1-rmse:0.13793
# [738]	validation_0-rmse:0.14682	validation_1-rmse:0.13798
# [740]	validation_0-rmse:0.14679	validation_1-rmse:0.13798
# [742]	validation_0-rmse:0.14671	validation_1-rmse:0.13799
# [744]	validation_0-rmse:0.14668	validation_1-rmse:0.13800
# [746]	validation_0-rmse:0.14662	validation_1-rmse:0.13800
# [748]	validation_0-rmse:0.14658	validation_1-rmse:0.13797
# [750]	validation_0-rmse:0.14655	validation_1-rmse:0.13795
# [752]	validation_0-rmse:0.14653	validation_1-rmse:0.13795
# [754]	validation_0-rmse:0.14645	validation_1-rmse:0.13793
# [756]	validation_0-rmse:0.14639	validation_1-rmse:0.13792
# [758]	validation_0-rmse:0.14634	validation_1-rmse:0.13793
# [760]	validation_0-rmse:0.14630	validation_1-rmse:0.13791
# [762]	validation_0-rmse:0.14628	validation_1-rmse:0.13792
# [764]	validation_0-rmse:0.14623	validation_1-rmse:0.13792
# [766]	validation_0-rmse:0.14619	validation_1-rmse:0.13790
# [768]	validation_0-rmse:0.14617	validation_1-rmse:0.13790
# [770]	validation_0-rmse:0.14614	validation_1-rmse:0.13788
# [772]	validation_0-rmse:0.14610	validation_1-rmse:0.13788
# [774]	validation_0-rmse:0.14608	validation_1-rmse:0.13788
# [776]	validation_0-rmse:0.14604	validation_1-rmse:0.13789
# [778]	validation_0-rmse:0.14597	validation_1-rmse:0.13795
# [780]	validation_0-rmse:0.14592	validation_1-rmse:0.13794
# [782]	validation_0-rmse:0.14590	validation_1-rmse:0.13794
# [784]	validation_0-rmse:0.14587	validation_1-rmse:0.13795
# [786]	validation_0-rmse:0.14582	validation_1-rmse:0.13795
# [788]	validation_0-rmse:0.14581	validation_1-rmse:0.13795
# [790]	validation_0-rmse:0.14579	validation_1-rmse:0.13794
# [792]	validation_0-rmse:0.14578	validation_1-rmse:0.13794
# [794]	validation_0-rmse:0.14576	validation_1-rmse:0.13794
# [796]	validation_0-rmse:0.14570	validation_1-rmse:0.13792
# [798]	validation_0-rmse:0.14566	validation_1-rmse:0.13792
# [800]	validation_0-rmse:0.14562	validation_1-rmse:0.13791
# [802]	validation_0-rmse:0.14561	validation_1-rmse:0.13791
# [804]	validation_0-rmse:0.14556	validation_1-rmse:0.13793
# [806]	validation_0-rmse:0.14549	validation_1-rmse:0.13793
# [808]	validation_0-rmse:0.14542	validation_1-rmse:0.13792
# [810]	validation_0-rmse:0.14538	validation_1-rmse:0.13792
# [812]	validation_0-rmse:0.14534	validation_1-rmse:0.13791
# [814]	validation_0-rmse:0.14529	validation_1-rmse:0.13792
# [816]	validation_0-rmse:0.14527	validation_1-rmse:0.13793
# [818]	validation_0-rmse:0.14523	validation_1-rmse:0.13792
# [820]	validation_0-rmse:0.14519	validation_1-rmse:0.13794
# [822]	validation_0-rmse:0.14515	validation_1-rmse:0.13794
# [824]	validation_0-rmse:0.14513	validation_1-rmse:0.13793
# [826]	validation_0-rmse:0.14508	validation_1-rmse:0.13792
# [828]	validation_0-rmse:0.14507	validation_1-rmse:0.13792
# [830]	validation_0-rmse:0.14503	validation_1-rmse:0.13792
# [832]	validation_0-rmse:0.14500	validation_1-rmse:0.13792
# [834]	validation_0-rmse:0.14496	validation_1-rmse:0.13792
# [836]	validation_0-rmse:0.14490	validation_1-rmse:0.13791
# [838]	validation_0-rmse:0.14487	validation_1-rmse:0.13791
# [840]	validation_0-rmse:0.14483	validation_1-rmse:0.13789
# [842]	validation_0-rmse:0.14479	validation_1-rmse:0.13789
# [844]	validation_0-rmse:0.14475	validation_1-rmse:0.13789
# [846]	validation_0-rmse:0.14472	validation_1-rmse:0.13790
# [848]	validation_0-rmse:0.14470	validation_1-rmse:0.13789
# [850]	validation_0-rmse:0.14463	validation_1-rmse:0.13789
# [852]	validation_0-rmse:0.14459	validation_1-rmse:0.13790
# [854]	validation_0-rmse:0.14456	validation_1-rmse:0.13790
# [856]	validation_0-rmse:0.14454	validation_1-rmse:0.13789
# [858]	validation_0-rmse:0.14451	validation_1-rmse:0.13792
# [860]	validation_0-rmse:0.14447	validation_1-rmse:0.13792
# [862]	validation_0-rmse:0.14445	validation_1-rmse:0.13792
# [864]	validation_0-rmse:0.14442	validation_1-rmse:0.13792
# [866]	validation_0-rmse:0.14437	validation_1-rmse:0.13793
# [868]	validation_0-rmse:0.14435	validation_1-rmse:0.13791
# [870]	validation_0-rmse:0.14434	validation_1-rmse:0.13791
# [872]	validation_0-rmse:0.14430	validation_1-rmse:0.13792
# [874]	validation_0-rmse:0.14426	validation_1-rmse:0.13791
# [876]	validation_0-rmse:0.14421	validation_1-rmse:0.13790
# [878]	validation_0-rmse:0.14417	validation_1-rmse:0.13790
# [880]	validation_0-rmse:0.14413	validation_1-rmse:0.13790
# [882]	validation_0-rmse:0.14409	validation_1-rmse:0.13791
# [884]	validation_0-rmse:0.14406	validation_1-rmse:0.13791
# [886]	validation_0-rmse:0.14404	validation_1-rmse:0.13790
# [888]	validation_0-rmse:0.14403	validation_1-rmse:0.13790
# [890]	validation_0-rmse:0.14399	validation_1-rmse:0.13790
# [892]	validation_0-rmse:0.14395	validation_1-rmse:0.13790
# [894]	validation_0-rmse:0.14391	validation_1-rmse:0.13790
# [896]	validation_0-rmse:0.14389	validation_1-rmse:0.13789
# [898]	validation_0-rmse:0.14386	validation_1-rmse:0.13790
# [900]	validation_0-rmse:0.14383	validation_1-rmse:0.13790
# [902]	validation_0-rmse:0.14376	validation_1-rmse:0.13789
# [904]	validation_0-rmse:0.14372	validation_1-rmse:0.13789
# [906]	validation_0-rmse:0.14368	validation_1-rmse:0.13788
# [908]	validation_0-rmse:0.14364	validation_1-rmse:0.13788
# [910]	validation_0-rmse:0.14360	validation_1-rmse:0.13787
# [912]	validation_0-rmse:0.14355	validation_1-rmse:0.13786
# [914]	validation_0-rmse:0.14350	validation_1-rmse:0.13784
# [916]	validation_0-rmse:0.14347	validation_1-rmse:0.13784
# [918]	validation_0-rmse:0.14343	validation_1-rmse:0.13784
# [920]	validation_0-rmse:0.14341	validation_1-rmse:0.13784
# [922]	validation_0-rmse:0.14339	validation_1-rmse:0.13785
# [924]	validation_0-rmse:0.14336	validation_1-rmse:0.13785
# [926]	validation_0-rmse:0.14334	validation_1-rmse:0.13785
# [928]	validation_0-rmse:0.14332	validation_1-rmse:0.13784
# [930]	validation_0-rmse:0.14329	validation_1-rmse:0.13784
# [932]	validation_0-rmse:0.14326	validation_1-rmse:0.13796
# [934]	validation_0-rmse:0.14322	validation_1-rmse:0.13795
# [936]	validation_0-rmse:0.14320	validation_1-rmse:0.13794
# [938]	validation_0-rmse:0.14318	validation_1-rmse:0.13795
# [940]	validation_0-rmse:0.14315	validation_1-rmse:0.13795
# [942]	validation_0-rmse:0.14311	validation_1-rmse:0.13794
# [944]	validation_0-rmse:0.14306	validation_1-rmse:0.13795
# [946]	validation_0-rmse:0.14303	validation_1-rmse:0.13796
# [948]	validation_0-rmse:0.14302	validation_1-rmse:0.13797
# [950]	validation_0-rmse:0.14299	validation_1-rmse:0.13796
# [952]	validation_0-rmse:0.14293	validation_1-rmse:0.13796
# [954]	validation_0-rmse:0.14288	validation_1-rmse:0.13795
# [956]	validation_0-rmse:0.14284	validation_1-rmse:0.13796
# [958]	validation_0-rmse:0.14281	validation_1-rmse:0.13795
# [960]	validation_0-rmse:0.14276	validation_1-rmse:0.13795
# [962]	validation_0-rmse:0.14272	validation_1-rmse:0.13795
# [964]	validation_0-rmse:0.14266	validation_1-rmse:0.13794
# [966]	validation_0-rmse:0.14261	validation_1-rmse:0.13793
# [968]	validation_0-rmse:0.14258	validation_1-rmse:0.13793
# [970]	validation_0-rmse:0.14254	validation_1-rmse:0.13793
# [972]	validation_0-rmse:0.14250	validation_1-rmse:0.13794
# [974]	validation_0-rmse:0.14244	validation_1-rmse:0.13793
# [976]	validation_0-rmse:0.14241	validation_1-rmse:0.13793
# [978]	validation_0-rmse:0.14236	validation_1-rmse:0.13792
# [980]	validation_0-rmse:0.14233	validation_1-rmse:0.13790
# [982]	validation_0-rmse:0.14231	validation_1-rmse:0.13791
# [984]	validation_0-rmse:0.14227	validation_1-rmse:0.13790
# [986]	validation_0-rmse:0.14226	validation_1-rmse:0.13790
# [988]	validation_0-rmse:0.14224	validation_1-rmse:0.13790
# [990]	validation_0-rmse:0.14222	validation_1-rmse:0.13790
# [992]	validation_0-rmse:0.14219	validation_1-rmse:0.13790
# [994]	validation_0-rmse:0.14217	validation_1-rmse:0.13790
# [996]	validation_0-rmse:0.14212	validation_1-rmse:0.13790
# [998]	validation_0-rmse:0.14209	validation_1-rmse:0.13789
# [1000]	validation_0-rmse:0.14206	validation_1-rmse:0.13790
# [1002]	validation_0-rmse:0.14202	validation_1-rmse:0.13791
# [1004]	validation_0-rmse:0.14200	validation_1-rmse:0.13792
# [1006]	validation_0-rmse:0.14197	validation_1-rmse:0.13792
# [1008]	validation_0-rmse:0.14195	validation_1-rmse:0.13792
# [1010]	validation_0-rmse:0.14193	validation_1-rmse:0.13792
# [1012]	validation_0-rmse:0.14189	validation_1-rmse:0.13791
# [1014]	validation_0-rmse:0.14185	validation_1-rmse:0.13794
# [1016]	validation_0-rmse:0.14184	validation_1-rmse:0.13793
# [1018]	validation_0-rmse:0.14181	validation_1-rmse:0.13794
# [1020]	validation_0-rmse:0.14178	validation_1-rmse:0.13793
# [1022]	validation_0-rmse:0.14176	validation_1-rmse:0.13793
# [1024]	validation_0-rmse:0.14171	validation_1-rmse:0.13792
# [1026]	validation_0-rmse:0.14166	validation_1-rmse:0.13791
# [1028]	validation_0-rmse:0.14163	validation_1-rmse:0.13790
# [1030]	validation_0-rmse:0.14158	validation_1-rmse:0.13791
# [1032]	validation_0-rmse:0.14155	validation_1-rmse:0.13792
# [1034]	validation_0-rmse:0.14152	validation_1-rmse:0.13791
# [1036]	validation_0-rmse:0.14150	validation_1-rmse:0.13791
# [1038]	validation_0-rmse:0.14149	validation_1-rmse:0.13791
# [1040]	validation_0-rmse:0.14146	validation_1-rmse:0.13791
# [1042]	validation_0-rmse:0.14143	validation_1-rmse:0.13792
# [1044]	validation_0-rmse:0.14139	validation_1-rmse:0.13792
# [1046]	validation_0-rmse:0.14137	validation_1-rmse:0.13791
# [1048]	validation_0-rmse:0.14135	validation_1-rmse:0.13792
# [1050]	validation_0-rmse:0.14130	validation_1-rmse:0.13796
# [1052]	validation_0-rmse:0.14128	validation_1-rmse:0.13798
# [1054]	validation_0-rmse:0.14123	validation_1-rmse:0.13798
# [1056]	validation_0-rmse:0.14120	validation_1-rmse:0.13800
# [1058]	validation_0-rmse:0.14116	validation_1-rmse:0.13799
# [1060]	validation_0-rmse:0.14113	validation_1-rmse:0.13800
# [1062]	validation_0-rmse:0.14109	validation_1-rmse:0.13802
# [1064]	validation_0-rmse:0.14106	validation_1-rmse:0.13803
# [1066]	validation_0-rmse:0.14103	validation_1-rmse:0.13802
# [1068]	validation_0-rmse:0.14100	validation_1-rmse:0.13804
# [1070]	validation_0-rmse:0.14099	validation_1-rmse:0.13803
# [1072]	validation_0-rmse:0.14095	validation_1-rmse:0.13802
# [1074]	validation_0-rmse:0.14093	validation_1-rmse:0.13802
# [1076]	validation_0-rmse:0.14090	validation_1-rmse:0.13802
# [1078]	validation_0-rmse:0.14088	validation_1-rmse:0.13800
# [1080]	validation_0-rmse:0.14086	validation_1-rmse:0.13801
# [1082]	validation_0-rmse:0.14083	validation_1-rmse:0.13801
# [1084]	validation_0-rmse:0.14080	validation_1-rmse:0.13802
# [1086]	validation_0-rmse:0.14076	validation_1-rmse:0.13801
# [1088]	validation_0-rmse:0.14074	validation_1-rmse:0.13802
# [1090]	validation_0-rmse:0.14071	validation_1-rmse:0.13803
# [1092]	validation_0-rmse:0.14068	validation_1-rmse:0.13802
# [1094]	validation_0-rmse:0.14063	validation_1-rmse:0.13803
# [1096]	validation_0-rmse:0.14059	validation_1-rmse:0.13805
# [1098]	validation_0-rmse:0.14056	validation_1-rmse:0.13805
# [1100]	validation_0-rmse:0.14054	validation_1-rmse:0.13805
# [1102]	validation_0-rmse:0.14051	validation_1-rmse:0.13805
# [1104]	validation_0-rmse:0.14047	validation_1-rmse:0.13802
# [1106]	validation_0-rmse:0.14045	validation_1-rmse:0.13800
# [1108]	validation_0-rmse:0.14044	validation_1-rmse:0.13800
# [1110]	validation_0-rmse:0.14041	validation_1-rmse:0.13800
# [1112]	validation_0-rmse:0.14039	validation_1-rmse:0.13805
# [1114]	validation_0-rmse:0.14035	validation_1-rmse:0.13806
# [1116]	validation_0-rmse:0.14032	validation_1-rmse:0.13806
# [1118]	validation_0-rmse:0.14029	validation_1-rmse:0.13804
# [1120]	validation_0-rmse:0.14027	validation_1-rmse:0.13804
# [1122]	validation_0-rmse:0.14023	validation_1-rmse:0.13806
# [1124]	validation_0-rmse:0.14021	validation_1-rmse:0.13806
# [1126]	validation_0-rmse:0.14020	validation_1-rmse:0.13806
# [1128]	validation_0-rmse:0.14014	validation_1-rmse:0.13807
# [1130]	validation_0-rmse:0.14011	validation_1-rmse:0.13806
# [1132]	validation_0-rmse:0.14009	validation_1-rmse:0.13806
# [1134]	validation_0-rmse:0.14005	validation_1-rmse:0.13807
# [1136]	validation_0-rmse:0.14001	validation_1-rmse:0.13808
# [1138]	validation_0-rmse:0.13997	validation_1-rmse:0.13806
# [1140]	validation_0-rmse:0.13993	validation_1-rmse:0.13806
# [1142]	validation_0-rmse:0.13990	validation_1-rmse:0.13807
# [1144]	validation_0-rmse:0.13987	validation_1-rmse:0.13808
# [1146]	validation_0-rmse:0.13986	validation_1-rmse:0.13808
# [1148]	validation_0-rmse:0.13981	validation_1-rmse:0.13807
# [1150]	validation_0-rmse:0.13978	validation_1-rmse:0.13807
# [1152]	validation_0-rmse:0.13974	validation_1-rmse:0.13808
# [1154]	validation_0-rmse:0.13971	validation_1-rmse:0.13808
# [1156]	validation_0-rmse:0.13969	validation_1-rmse:0.13809
# [1158]	validation_0-rmse:0.13966	validation_1-rmse:0.13811
# [1160]	validation_0-rmse:0.13962	validation_1-rmse:0.13811
# [1162]	validation_0-rmse:0.13958	validation_1-rmse:0.13811
# [1164]	validation_0-rmse:0.13957	validation_1-rmse:0.13811
# [1166]	validation_0-rmse:0.13954	validation_1-rmse:0.13811
# [1168]	validation_0-rmse:0.13951	validation_1-rmse:0.13810
# [1170]	validation_0-rmse:0.13948	validation_1-rmse:0.13810
# [1172]	validation_0-rmse:0.13946	validation_1-rmse:0.13810
# [1174]	validation_0-rmse:0.13944	validation_1-rmse:0.13810
# [1176]	validation_0-rmse:0.13940	validation_1-rmse:0.13810
# [1178]	validation_0-rmse:0.13938	validation_1-rmse:0.13811
# [1180]	validation_0-rmse:0.13935	validation_1-rmse:0.13811
# [1182]	validation_0-rmse:0.13932	validation_1-rmse:0.13812
# [1184]	validation_0-rmse:0.13928	validation_1-rmse:0.13811
# [1186]	validation_0-rmse:0.13925	validation_1-rmse:0.13811
# [1188]	validation_0-rmse:0.13924	validation_1-rmse:0.13811
# [1190]	validation_0-rmse:0.13921	validation_1-rmse:0.13811
# [1192]	validation_0-rmse:0.13919	validation_1-rmse:0.13811
# [1194]	validation_0-rmse:0.13917	validation_1-rmse:0.13812
# [1196]	validation_0-rmse:0.13913	validation_1-rmse:0.13811
# [1198]	validation_0-rmse:0.13910	validation_1-rmse:0.13810
# [1200]	validation_0-rmse:0.13908	validation_1-rmse:0.13811
# [1202]	validation_0-rmse:0.13905	validation_1-rmse:0.13829
# [1204]	validation_0-rmse:0.13902	validation_1-rmse:0.13826
# [1206]	validation_0-rmse:0.13899	validation_1-rmse:0.13826
# [1208]	validation_0-rmse:0.13897	validation_1-rmse:0.13826
# [1210]	validation_0-rmse:0.13892	validation_1-rmse:0.13826
# [1212]	validation_0-rmse:0.13887	validation_1-rmse:0.13823
# [1214]	validation_0-rmse:0.13882	validation_1-rmse:0.13824
# [1216]	validation_0-rmse:0.13877	validation_1-rmse:0.13823
# [1218]	validation_0-rmse:0.13873	validation_1-rmse:0.13822
# [1220]	validation_0-rmse:0.13869	validation_1-rmse:0.13822
# [1222]	validation_0-rmse:0.13866	validation_1-rmse:0.13822
# [1224]	validation_0-rmse:0.13863	validation_1-rmse:0.13821
# [1226]	validation_0-rmse:0.13859	validation_1-rmse:0.13819
# [1228]	validation_0-rmse:0.13856	validation_1-rmse:0.13819
# [1230]	validation_0-rmse:0.13851	validation_1-rmse:0.13820
# [1232]	validation_0-rmse:0.13847	validation_1-rmse:0.13820
# [1234]	validation_0-rmse:0.13843	validation_1-rmse:0.13821
# [1236]	validation_0-rmse:0.13839	validation_1-rmse:0.13820
# [1238]	validation_0-rmse:0.13837	validation_1-rmse:0.13820
# [1240]	validation_0-rmse:0.13834	validation_1-rmse:0.13819
# [1242]	validation_0-rmse:0.13832	validation_1-rmse:0.13819
# [1244]	validation_0-rmse:0.13830	validation_1-rmse:0.13818
# [1246]	validation_0-rmse:0.13827	validation_1-rmse:0.13818
# [1248]	validation_0-rmse:0.13825	validation_1-rmse:0.13818
# [1250]	validation_0-rmse:0.13818	validation_1-rmse:0.13818
# [1252]	validation_0-rmse:0.13817	validation_1-rmse:0.13818
# [1254]	validation_0-rmse:0.13811	validation_1-rmse:0.13814
# [1256]	validation_0-rmse:0.13808	validation_1-rmse:0.13815
# [1258]	validation_0-rmse:0.13805	validation_1-rmse:0.13816
# [1260]	validation_0-rmse:0.13803	validation_1-rmse:0.13815
# [1262]	validation_0-rmse:0.13801	validation_1-rmse:0.13813
# [1264]	validation_0-rmse:0.13798	validation_1-rmse:0.13813
# [1266]	validation_0-rmse:0.13794	validation_1-rmse:0.13811
# [1268]	validation_0-rmse:0.13792	validation_1-rmse:0.13811
# [1270]	validation_0-rmse:0.13789	validation_1-rmse:0.13810
# [1272]	validation_0-rmse:0.13786	validation_1-rmse:0.13810
# [1274]	validation_0-rmse:0.13785	validation_1-rmse:0.13811
# [1276]	validation_0-rmse:0.13782	validation_1-rmse:0.13811
# [1278]	validation_0-rmse:0.13781	validation_1-rmse:0.13812
# [1280]	validation_0-rmse:0.13777	validation_1-rmse:0.13812
# [1282]	validation_0-rmse:0.13775	validation_1-rmse:0.13812
# [1284]	validation_0-rmse:0.13770	validation_1-rmse:0.13812
# [1286]	validation_0-rmse:0.13767	validation_1-rmse:0.13841
# [1288]	validation_0-rmse:0.13765	validation_1-rmse:0.13841
# [1290]	validation_0-rmse:0.13765	validation_1-rmse:0.13841
# [1292]	validation_0-rmse:0.13760	validation_1-rmse:0.13841
# [1294]	validation_0-rmse:0.13757	validation_1-rmse:0.13841
# [1296]	validation_0-rmse:0.13754	validation_1-rmse:0.13840
# [1298]	validation_0-rmse:0.13751	validation_1-rmse:0.13840
# [1299]	validation_0-rmse:0.13750	validation_1-rmse:0.13840

# %% [markdown]
# ## Predictions Evaluation

# %%
train_predict = model.predict(X_train).reshape(-1, 1)
test_predict = model.predict(X_test).reshape(-1, 1)

train_predict_inv = target_scaler.inverse_transform(train_predict)
test_predict_inv = target_scaler.inverse_transform(test_predict)

y_train_inv = target_scaler.inverse_transform(y_train)
y_test_inv = target_scaler.inverse_transform(y_test)

print('Train Mean Absolute Error:', mean_absolute_error(y_train_inv, train_predict_inv))
print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train_inv, train_predict_inv)))
print('Train R2 score:', r2_score(y_train_inv, train_predict_inv))

print('Test Mean Absolute Error:', mean_absolute_error(y_test_inv, test_predict_inv))
print('Test Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test_inv, test_predict_inv)))
print('Test R2 score:', r2_score(y_test_inv, test_predict_inv))
# Out:
# Train Mean Absolute Error: 0.060516061081832204
# Train Root Mean Squared Error: 0.1500967282557032
# Train R2 score: 0.9810924135092743
# Test Mean Absolute Error: 0.06640581372784607
# Test Root Mean Squared Error: 0.15107273421046127
# Test R2 score: 0.9716444092079979

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.plot(y_test, label='Actual')
plt.plot(test_predict, label='Predicted')
plt.title('XGBoost Prediction vs Actual')
plt.legend()
plt.show()

# %%
indice = 400 #number of testing examples to use

limit = [x for x in range(indice)]
plt.figure(figsize=(20,6))

plt.plot(limit, y_test[:indice], label="actual", color='green')
plt.plot(limit, test_predict[:,0][:indice], '-', label="prediction", color='red')

plt.ylabel('Global_active_power')
plt.xlabel('Time step in minutes')
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# ## Evaluation Across a Time Series Split:
#
# Cross validation using a five fold time series split to predict the general trends within the data.

# %%
from sklearn.model_selection import TimeSeriesSplit, cross_val_score

timecrossval = TimeSeriesSplit(n_splits=5)

scores = cross_val_score(model, np.concatenate([X_train, X_test], axis=0), np.concatenate([y_train, y_test], axis=0), cv=timecrossval, scoring='r2')

print("R2 scores for all folds: ", scores)
print("Mean R2 score: ", scores.mean())
# Out:
# R2 scores for all folds:  [0.94018392 0.91607477 0.96798648 0.97247276 0.97220889]
# Mean R2 score:  0.9537853673183694

# %% [markdown]
# ## Conclusion:
#
# The model is predicting the electric power usage in a time-series bound way and is returning efficient results.
