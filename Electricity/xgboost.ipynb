# %% [markdown]
# # Household Electric Power Consumption
#
# Method used: XGBoost with rolling lags, preprocessing and window shifting.
#
# ### By Pratham Shah (B.Tech CSE, 240905614, 2028) for the Cryptonite Research Taskphase

# %% [markdown]
# ## Imports and Loading the Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
df = df.copy()
# Out:
# /tmp/ipykernel_74263/199733144.py:8: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
# /tmp/ipykernel_74263/199733144.py:8: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])
# /tmp/ipykernel_74263/199733144.py:8: UserWarning: Parsing dates in %d/%m/%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv("household_power_consumption.txt", sep=";", parse_dates={'date_time' : ['Date', 'Time']}, infer_datetime_format=True, na_values=['nan','?'])

# %% [markdown]
# # EDA

# %%
print("DATA INFORMATION:")
print(df.info())
print("\n\nDATA DESCRIPTION")
print(df.describe())
# Out:
# DATA INFORMATION:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 8 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   date_time              datetime64[ns]
#  1   Global_active_power    float64
#  2   Global_reactive_power  float64
#  3   Voltage                float64
#  4   Global_intensity       float64
#  5   Sub_metering_1         float64
#  6   Sub_metering_2         float64
#  7   Sub_metering_3         float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 126.7 MB
# None
#
#
# DATA DESCRIPTION
#                            date_time  Global_active_power  \
# count                        2075259         2.049280e+06
# mean   2008-12-06 07:12:59.999994112         1.091615e+00
# min              2006-12-16 17:24:00         7.600000e-02
# 25%              2007-12-12 00:18:30         3.080000e-01
# 50%              2008-12-06 07:13:00         6.020000e-01
# 75%              2009-12-01 14:07:30         1.528000e+00
# max              2010-11-26 21:02:00         1.112200e+01
# std                              NaN         1.057294e+00
#
#        Global_reactive_power       Voltage  Global_intensity  Sub_metering_1  \
# count           2.049280e+06  2.049280e+06      2.049280e+06    2.049280e+06
# mean            1.237145e-01  2.408399e+02      4.627759e+00    1.121923e+00
# min             0.000000e+00  2.232000e+02      2.000000e-01    0.000000e+00
# 25%             4.800000e-02  2.389900e+02      1.400000e+00    0.000000e+00
# 50%             1.000000e-01  2.410100e+02      2.600000e+00    0.000000e+00
# 75%             1.940000e-01  2.428900e+02      6.400000e+00    0.000000e+00
# max             1.390000e+00  2.541500e+02      4.840000e+01    8.800000e+01
# std             1.127220e-01  3.239987e+00      4.444396e+00    6.153031e+00
#
#        Sub_metering_2  Sub_metering_3
# count    2.049280e+06    2.049280e+06
# mean     1.298520e+00    6.458447e+00
# min      0.000000e+00    0.000000e+00
# 25%      0.000000e+00    0.000000e+00
# 50%      0.000000e+00    1.000000e+00
# 75%      1.000000e+00    1.700000e+01
# max      8.000000e+01    3.100000e+01
# std      5.822026e+00    8.437154e+00

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Global_active_power'], label='Global Active Power')
plt.title('Global Active Power Over Time')
plt.ylabel('Power (kilowatts)')
plt.xlabel('Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
df_temp = df.copy()
hourly_avg = df_temp.groupby(df_temp["date_time"].dt.hour)['Global_active_power'].mean()

plt.figure(figsize=(12, 4))
hourly_avg.plot(kind='bar')
plt.title('Average Power Usage by Hour')
plt.xlabel('Hour of Day')
plt.ylabel('Avg Power (kW)')
plt.grid(True)
plt.show()

# %%
df_temp['day_name'] = df_temp["date_time"].dt.day_name()

plt.figure(figsize=(10, 5))
sns.boxplot(x='day_name', y='Global_active_power', data=df_temp)
plt.title('Power Usage by Day of Week')
plt.xticks(rotation=45)
plt.show()

# %%
from pandas.plotting import autocorrelation_plot
import matplotlib.pyplot as plt

df_temp.set_index('date_time', inplace=True)
df_daily = df_temp['Global_active_power'].resample('D').mean()

plt.figure(figsize=(10, 4))
autocorrelation_plot(df_daily.dropna())
plt.title('Daily Autocorrelation')
plt.xlabel('Lag (days)')
plt.ylabel('Autocorrelation')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
df['year'] = df['date_time'].dt.year
df['quarter'] = df['date_time'].dt.quarter
df['month'] = df['date_time'].dt.month
df['day'] = df['date_time'].dt.day
df['hour_of_day'] = df['date_time'].dt.hour #creating new columns to better capture time dependencies
df['is_weekend'] = df['date_time'].dt.dayofweek >= 5
df['is_weekend'] = df['is_weekend'].astype(int)  #weekend : 1, weekday : 0. idea is that weekend signifies greater consumption

# Lag features
for lag in [1, 30, 60, 1440]:
    df[f'lag_{lag}_min'] = df['Global_active_power'].shift(lag)

# Rolling statistics
df['rolling_mean_60'] = df['Global_active_power'].rolling(window=60).mean()
df['rolling_std_60'] = df['Global_active_power'].rolling(window=60).std()
    
df.sort_values('date_time', inplace=True, ascending=True)
df = df.reset_index(drop=True)

df.dropna(inplace=True) #drop all null/nan values introduced by rolling lag and within the dataset

df
# Out:
#                   date_time  Global_active_power  Global_reactive_power  \
# 1440    2006-12-17 17:24:00                3.390                  0.170
# 1441    2006-12-17 17:25:00                3.360                  0.164
# 1442    2006-12-17 17:26:00                3.400                  0.162
# 1443    2006-12-17 17:27:00                3.396                  0.164
# 1444    2006-12-17 17:28:00                3.282                  0.100
# ...                     ...                  ...                    ...
# 2075254 2010-11-26 20:58:00                0.946                  0.000
# 2075255 2010-11-26 20:59:00                0.944                  0.000
# 2075256 2010-11-26 21:00:00                0.938                  0.000
# 2075257 2010-11-26 21:01:00                0.934                  0.000
# 2075258 2010-11-26 21:02:00                0.932                  0.000
#
#          Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# 1440      232.65              14.6             0.0             0.0
# 1441      231.20              14.4             0.0             0.0
# 1442      232.86              14.6             0.0             0.0
# 1443      232.89              14.6             0.0             0.0
# 1444      232.33              14.0             0.0             0.0
# ...          ...               ...             ...             ...
# 2075254   240.43               4.0             0.0             0.0
# 2075255   240.00               4.0             0.0             0.0
# 2075256   239.82               3.8             0.0             0.0
# 2075257   239.70               3.8             0.0             0.0
# 2075258   239.55               3.8             0.0             0.0
#
#          Sub_metering_3  year  quarter  month  day  hour_of_day  is_weekend  \
# 1440               17.0  2006        4     12   17           17           1
# 1441               16.0  2006        4     12   17           17           1
# 1442               17.0  2006        4     12   17           17           1
# 1443               17.0  2006        4     12   17           17           1
# 1444               16.0  2006        4     12   17           17           1
# ...                 ...   ...      ...    ...  ...          ...         ...
# 2075254             0.0  2010        4     11   26           20           0
# 2075255             0.0  2010        4     11   26           20           0
# 2075256             0.0  2010        4     11   26           21           0
# 2075257             0.0  2010        4     11   26           21           0
# 2075258             0.0  2010        4     11   26           21           0
#
#          lag_1_min  lag_30_min  lag_60_min  lag_1440_min  rolling_mean_60  \
# 1440         3.238       3.328       4.864         4.216         3.527967
# 1441         3.390       3.316       4.868         5.360         3.502833
# 1442         3.360       3.390       4.876         5.374         3.478233
# 1443         3.400       3.418       4.810         5.388         3.454667
# 1444         3.396       3.384       4.790         3.666         3.429533
# ...            ...         ...         ...           ...              ...
# 2075254      0.946       0.982       1.526         1.522         1.173367
# 2075255      0.946       0.958       1.524         1.518         1.163700
# 2075256      0.944       0.980       1.456         1.512         1.155067
# 2075257      0.938       0.982       1.554         1.508         1.144733
# 2075258      0.934       0.982       1.596         1.502         1.133667
#
#          rolling_std_60
# 1440           0.671762
# 1441           0.648586
# 1442           0.623112
# 1443           0.598129
# 1444           0.572188
# ...                 ...
# 2075254        0.312391
# 2075255        0.310324
# 2075256        0.309258
# 2075257        0.306044
# 2075258        0.301420
#
# [2034118 rows x 20 columns]

# %%
df.drop(["Global_intensity", "date_time"], axis=1, inplace=True)

print('Number of rows and columns:', df.shape)
# Out:
# Number of rows and columns: (2034118, 18)

# %% [markdown]
# ## Preparation for the Model

# %%
target_col = 'Global_active_power'
features = df.drop(columns=[target_col])
target = df[target_col] #split target and x

split_index = int(len(df) * 0.8) #0.8 split of train and test data

X_train_raw, X_test_raw = features[:split_index], features[split_index:]
y_train_raw, y_test_raw = target[:split_index], target[split_index:]

feature_scaler = StandardScaler()
X_train = pd.DataFrame(
    feature_scaler.fit_transform(X_train_raw),
    columns=X_train_raw.columns,
    index=X_train_raw.index
)
X_test = pd.DataFrame(
    feature_scaler.transform(X_test_raw),
    columns=X_test_raw.columns,
    index=X_test_raw.index
)

target_scaler = StandardScaler() #different scaler for target - needed to invert
y_train = target_scaler.fit_transform(y_train_raw.values.reshape(-1, 1))
y_test = target_scaler.transform(y_test_raw.values.reshape(-1, 1))

# %% [markdown]
# ## The Model

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=500, learning_rate=0.2)

eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train,
          eval_set=eval_set,
          verbose=2)

results = model.evals_result()

epochs = len(results['validation_0']['rmse'])
x_axis = range(epochs)

plt.figure(figsize=(10, 5))
plt.plot(x_axis, results['validation_0']['rmse'], label='Train RMSE')
plt.plot(x_axis, results['validation_1']['rmse'], label='Validation RMSE')
plt.title('XGBoost Training vs Validation RMSE')
plt.xlabel('Boosting Round')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [0]	validation_0-rmse:0.81205	validation_1-rmse:0.66705
# [2]	validation_0-rmse:0.54763	validation_1-rmse:0.44420
# [4]	validation_0-rmse:0.38858	validation_1-rmse:0.31063
# [6]	validation_0-rmse:0.29739	validation_1-rmse:0.23415
# [8]	validation_0-rmse:0.24873	validation_1-rmse:0.19429
# [10]	validation_0-rmse:0.22273	validation_1-rmse:0.17352
# [12]	validation_0-rmse:0.20892	validation_1-rmse:0.16298
# [14]	validation_0-rmse:0.20111	validation_1-rmse:0.15787
# [16]	validation_0-rmse:0.19625	validation_1-rmse:0.15515
# [18]	validation_0-rmse:0.19291	validation_1-rmse:0.15318
# [20]	validation_0-rmse:0.19074	validation_1-rmse:0.15153
# [22]	validation_0-rmse:0.18880	validation_1-rmse:0.15053
# [24]	validation_0-rmse:0.18698	validation_1-rmse:0.14963
# [26]	validation_0-rmse:0.18558	validation_1-rmse:0.14883
# [28]	validation_0-rmse:0.18461	validation_1-rmse:0.14835
# [30]	validation_0-rmse:0.18364	validation_1-rmse:0.14790
# [32]	validation_0-rmse:0.18284	validation_1-rmse:0.14732
# [34]	validation_0-rmse:0.18198	validation_1-rmse:0.14707
# [36]	validation_0-rmse:0.18147	validation_1-rmse:0.14683
# [38]	validation_0-rmse:0.18024	validation_1-rmse:0.14603
# [40]	validation_0-rmse:0.17975	validation_1-rmse:0.14577
# [42]	validation_0-rmse:0.17908	validation_1-rmse:0.14533
# [44]	validation_0-rmse:0.17871	validation_1-rmse:0.14516
# [46]	validation_0-rmse:0.17798	validation_1-rmse:0.14499
# [48]	validation_0-rmse:0.17761	validation_1-rmse:0.14490
# [50]	validation_0-rmse:0.17714	validation_1-rmse:0.14475
# [52]	validation_0-rmse:0.17676	validation_1-rmse:0.14459
# [54]	validation_0-rmse:0.17640	validation_1-rmse:0.14447
# [56]	validation_0-rmse:0.17592	validation_1-rmse:0.14425
# [58]	validation_0-rmse:0.17546	validation_1-rmse:0.14404
# [60]	validation_0-rmse:0.17508	validation_1-rmse:0.14392
# [62]	validation_0-rmse:0.17483	validation_1-rmse:0.14389
# [64]	validation_0-rmse:0.17428	validation_1-rmse:0.14361
# [66]	validation_0-rmse:0.17399	validation_1-rmse:0.14357
# [68]	validation_0-rmse:0.17358	validation_1-rmse:0.14336
# [70]	validation_0-rmse:0.17340	validation_1-rmse:0.14332
# [72]	validation_0-rmse:0.17300	validation_1-rmse:0.14320
# [74]	validation_0-rmse:0.17278	validation_1-rmse:0.14317
# [76]	validation_0-rmse:0.17249	validation_1-rmse:0.14310
# [78]	validation_0-rmse:0.17226	validation_1-rmse:0.14302
# [80]	validation_0-rmse:0.17197	validation_1-rmse:0.14291
# [82]	validation_0-rmse:0.17178	validation_1-rmse:0.14282
# [84]	validation_0-rmse:0.17141	validation_1-rmse:0.14280
# [86]	validation_0-rmse:0.17120	validation_1-rmse:0.14279
# [88]	validation_0-rmse:0.17090	validation_1-rmse:0.14267
# [90]	validation_0-rmse:0.17064	validation_1-rmse:0.14259
# [92]	validation_0-rmse:0.17038	validation_1-rmse:0.14251
# [94]	validation_0-rmse:0.17014	validation_1-rmse:0.14254
# [96]	validation_0-rmse:0.16991	validation_1-rmse:0.14244
# [98]	validation_0-rmse:0.16966	validation_1-rmse:0.14239
# [100]	validation_0-rmse:0.16944	validation_1-rmse:0.14226
# [102]	validation_0-rmse:0.16926	validation_1-rmse:0.14227
# [104]	validation_0-rmse:0.16894	validation_1-rmse:0.14216
# [106]	validation_0-rmse:0.16870	validation_1-rmse:0.14211
# [108]	validation_0-rmse:0.16855	validation_1-rmse:0.14219
# [110]	validation_0-rmse:0.16843	validation_1-rmse:0.14210
# [112]	validation_0-rmse:0.16834	validation_1-rmse:0.14208
# [114]	validation_0-rmse:0.16810	validation_1-rmse:0.14201
# [116]	validation_0-rmse:0.16785	validation_1-rmse:0.14196
# [118]	validation_0-rmse:0.16774	validation_1-rmse:0.14190
# [120]	validation_0-rmse:0.16760	validation_1-rmse:0.14187
# [122]	validation_0-rmse:0.16743	validation_1-rmse:0.14184
# [124]	validation_0-rmse:0.16721	validation_1-rmse:0.14181
# [126]	validation_0-rmse:0.16699	validation_1-rmse:0.14178
# [128]	validation_0-rmse:0.16692	validation_1-rmse:0.14178
# [130]	validation_0-rmse:0.16665	validation_1-rmse:0.14169
# [132]	validation_0-rmse:0.16655	validation_1-rmse:0.14167
# [134]	validation_0-rmse:0.16638	validation_1-rmse:0.14163
# [136]	validation_0-rmse:0.16627	validation_1-rmse:0.14161
# [138]	validation_0-rmse:0.16609	validation_1-rmse:0.14157
# [140]	validation_0-rmse:0.16597	validation_1-rmse:0.14149
# [142]	validation_0-rmse:0.16584	validation_1-rmse:0.14149
# [144]	validation_0-rmse:0.16567	validation_1-rmse:0.14142
# [146]	validation_0-rmse:0.16557	validation_1-rmse:0.14144
# [148]	validation_0-rmse:0.16544	validation_1-rmse:0.14137
# [150]	validation_0-rmse:0.16529	validation_1-rmse:0.14125
# [152]	validation_0-rmse:0.16512	validation_1-rmse:0.14117
# [154]	validation_0-rmse:0.16500	validation_1-rmse:0.14122
# [156]	validation_0-rmse:0.16486	validation_1-rmse:0.14116
# [158]	validation_0-rmse:0.16475	validation_1-rmse:0.14118
# [160]	validation_0-rmse:0.16453	validation_1-rmse:0.14117
# [162]	validation_0-rmse:0.16435	validation_1-rmse:0.14108
# [164]	validation_0-rmse:0.16417	validation_1-rmse:0.14108
# [166]	validation_0-rmse:0.16409	validation_1-rmse:0.14107
# [168]	validation_0-rmse:0.16398	validation_1-rmse:0.14108
# [170]	validation_0-rmse:0.16387	validation_1-rmse:0.14101
# [172]	validation_0-rmse:0.16363	validation_1-rmse:0.14096
# [174]	validation_0-rmse:0.16348	validation_1-rmse:0.14087
# [176]	validation_0-rmse:0.16338	validation_1-rmse:0.14087
# [178]	validation_0-rmse:0.16329	validation_1-rmse:0.14089
# [180]	validation_0-rmse:0.16320	validation_1-rmse:0.14101
# [182]	validation_0-rmse:0.16312	validation_1-rmse:0.14103
# [184]	validation_0-rmse:0.16296	validation_1-rmse:0.14108
# [186]	validation_0-rmse:0.16281	validation_1-rmse:0.14107
# [188]	validation_0-rmse:0.16258	validation_1-rmse:0.14103
# [190]	validation_0-rmse:0.16244	validation_1-rmse:0.14098
# [192]	validation_0-rmse:0.16236	validation_1-rmse:0.14098
# [194]	validation_0-rmse:0.16224	validation_1-rmse:0.14098
# [196]	validation_0-rmse:0.16218	validation_1-rmse:0.14110
# [198]	validation_0-rmse:0.16189	validation_1-rmse:0.14105
# [200]	validation_0-rmse:0.16182	validation_1-rmse:0.14111
# [202]	validation_0-rmse:0.16172	validation_1-rmse:0.14111
# [204]	validation_0-rmse:0.16150	validation_1-rmse:0.14106
# [206]	validation_0-rmse:0.16132	validation_1-rmse:0.14099
# [208]	validation_0-rmse:0.16107	validation_1-rmse:0.14097
# [210]	validation_0-rmse:0.16097	validation_1-rmse:0.14097
# [212]	validation_0-rmse:0.16086	validation_1-rmse:0.14091
# [214]	validation_0-rmse:0.16076	validation_1-rmse:0.14090
# [216]	validation_0-rmse:0.16059	validation_1-rmse:0.14093
# [218]	validation_0-rmse:0.16056	validation_1-rmse:0.14094
# [220]	validation_0-rmse:0.16052	validation_1-rmse:0.14093
# [222]	validation_0-rmse:0.16039	validation_1-rmse:0.14095
# [224]	validation_0-rmse:0.16029	validation_1-rmse:0.14094
# [226]	validation_0-rmse:0.16017	validation_1-rmse:0.14109
# [228]	validation_0-rmse:0.16005	validation_1-rmse:0.14106
# [230]	validation_0-rmse:0.16000	validation_1-rmse:0.14110
# [232]	validation_0-rmse:0.15989	validation_1-rmse:0.14106
# [234]	validation_0-rmse:0.15972	validation_1-rmse:0.14096
# [236]	validation_0-rmse:0.15962	validation_1-rmse:0.14098
# [238]	validation_0-rmse:0.15952	validation_1-rmse:0.14096
# [240]	validation_0-rmse:0.15949	validation_1-rmse:0.14095
# [242]	validation_0-rmse:0.15940	validation_1-rmse:0.14092
# [244]	validation_0-rmse:0.15936	validation_1-rmse:0.14089
# [246]	validation_0-rmse:0.15926	validation_1-rmse:0.14090
# [248]	validation_0-rmse:0.15913	validation_1-rmse:0.14084
# [250]	validation_0-rmse:0.15903	validation_1-rmse:0.14087
# [252]	validation_0-rmse:0.15887	validation_1-rmse:0.14088
# [254]	validation_0-rmse:0.15881	validation_1-rmse:0.14089
# [256]	validation_0-rmse:0.15872	validation_1-rmse:0.14086
# [258]	validation_0-rmse:0.15857	validation_1-rmse:0.14082
# [260]	validation_0-rmse:0.15849	validation_1-rmse:0.14079
# [262]	validation_0-rmse:0.15833	validation_1-rmse:0.14071
# [264]	validation_0-rmse:0.15823	validation_1-rmse:0.14073
# [266]	validation_0-rmse:0.15814	validation_1-rmse:0.14079
# [268]	validation_0-rmse:0.15806	validation_1-rmse:0.14079
# [270]	validation_0-rmse:0.15803	validation_1-rmse:0.14079
# [272]	validation_0-rmse:0.15794	validation_1-rmse:0.14075
# [274]	validation_0-rmse:0.15782	validation_1-rmse:0.14072
# [276]	validation_0-rmse:0.15773	validation_1-rmse:0.14068
# [278]	validation_0-rmse:0.15766	validation_1-rmse:0.14069
# [280]	validation_0-rmse:0.15759	validation_1-rmse:0.14068
# [282]	validation_0-rmse:0.15755	validation_1-rmse:0.14069
# [284]	validation_0-rmse:0.15744	validation_1-rmse:0.14069
# [286]	validation_0-rmse:0.15730	validation_1-rmse:0.14056
# [288]	validation_0-rmse:0.15721	validation_1-rmse:0.14055
# [290]	validation_0-rmse:0.15709	validation_1-rmse:0.14056
# [292]	validation_0-rmse:0.15703	validation_1-rmse:0.14055
# [294]	validation_0-rmse:0.15696	validation_1-rmse:0.14050
# [296]	validation_0-rmse:0.15689	validation_1-rmse:0.14048
# [298]	validation_0-rmse:0.15675	validation_1-rmse:0.14048
# [300]	validation_0-rmse:0.15669	validation_1-rmse:0.14048
# [302]	validation_0-rmse:0.15663	validation_1-rmse:0.14047
# [304]	validation_0-rmse:0.15658	validation_1-rmse:0.14043
# [306]	validation_0-rmse:0.15654	validation_1-rmse:0.14042
# [308]	validation_0-rmse:0.15644	validation_1-rmse:0.14041
# [310]	validation_0-rmse:0.15637	validation_1-rmse:0.14039
# [312]	validation_0-rmse:0.15626	validation_1-rmse:0.14050
# [314]	validation_0-rmse:0.15616	validation_1-rmse:0.14050
# [316]	validation_0-rmse:0.15610	validation_1-rmse:0.14069
# [318]	validation_0-rmse:0.15600	validation_1-rmse:0.14068
# [320]	validation_0-rmse:0.15596	validation_1-rmse:0.14066
# [322]	validation_0-rmse:0.15589	validation_1-rmse:0.14070
# [324]	validation_0-rmse:0.15581	validation_1-rmse:0.14068
# [326]	validation_0-rmse:0.15572	validation_1-rmse:0.14067
# [328]	validation_0-rmse:0.15563	validation_1-rmse:0.14066
# [330]	validation_0-rmse:0.15558	validation_1-rmse:0.14076
# [332]	validation_0-rmse:0.15553	validation_1-rmse:0.14076
# [334]	validation_0-rmse:0.15545	validation_1-rmse:0.14073
# [336]	validation_0-rmse:0.15538	validation_1-rmse:0.14072
# [338]	validation_0-rmse:0.15528	validation_1-rmse:0.14069
# [340]	validation_0-rmse:0.15523	validation_1-rmse:0.14070
# [342]	validation_0-rmse:0.15512	validation_1-rmse:0.14072
# [344]	validation_0-rmse:0.15505	validation_1-rmse:0.14072
# [346]	validation_0-rmse:0.15505	validation_1-rmse:0.14073
# [348]	validation_0-rmse:0.15499	validation_1-rmse:0.14071
# [350]	validation_0-rmse:0.15487	validation_1-rmse:0.14068
# [352]	validation_0-rmse:0.15481	validation_1-rmse:0.14068
# [354]	validation_0-rmse:0.15471	validation_1-rmse:0.14063
# [356]	validation_0-rmse:0.15464	validation_1-rmse:0.14064
# [358]	validation_0-rmse:0.15459	validation_1-rmse:0.14064
# [360]	validation_0-rmse:0.15448	validation_1-rmse:0.14064
# [362]	validation_0-rmse:0.15442	validation_1-rmse:0.14062
# [364]	validation_0-rmse:0.15434	validation_1-rmse:0.14062
# [366]	validation_0-rmse:0.15431	validation_1-rmse:0.14061
# [368]	validation_0-rmse:0.15427	validation_1-rmse:0.14061
# [370]	validation_0-rmse:0.15421	validation_1-rmse:0.14060
# [372]	validation_0-rmse:0.15410	validation_1-rmse:0.14054
# [374]	validation_0-rmse:0.15403	validation_1-rmse:0.14055
# [376]	validation_0-rmse:0.15397	validation_1-rmse:0.14055
# [378]	validation_0-rmse:0.15394	validation_1-rmse:0.14055
# [380]	validation_0-rmse:0.15384	validation_1-rmse:0.14054
# [382]	validation_0-rmse:0.15379	validation_1-rmse:0.14055
# [384]	validation_0-rmse:0.15368	validation_1-rmse:0.14052
# [386]	validation_0-rmse:0.15359	validation_1-rmse:0.14051
# [388]	validation_0-rmse:0.15351	validation_1-rmse:0.14049
# [390]	validation_0-rmse:0.15346	validation_1-rmse:0.14049
# [392]	validation_0-rmse:0.15340	validation_1-rmse:0.14048
# [394]	validation_0-rmse:0.15332	validation_1-rmse:0.14051
# [396]	validation_0-rmse:0.15324	validation_1-rmse:0.14050
# [398]	validation_0-rmse:0.15320	validation_1-rmse:0.14052
# [400]	validation_0-rmse:0.15317	validation_1-rmse:0.14059
# [402]	validation_0-rmse:0.15308	validation_1-rmse:0.14062
# [404]	validation_0-rmse:0.15302	validation_1-rmse:0.14065
# [406]	validation_0-rmse:0.15298	validation_1-rmse:0.14067
# [408]	validation_0-rmse:0.15292	validation_1-rmse:0.14064
# [410]	validation_0-rmse:0.15285	validation_1-rmse:0.14063
# [412]	validation_0-rmse:0.15279	validation_1-rmse:0.14065
# [414]	validation_0-rmse:0.15270	validation_1-rmse:0.14064
# [416]	validation_0-rmse:0.15263	validation_1-rmse:0.14064
# [418]	validation_0-rmse:0.15255	validation_1-rmse:0.14063
# [420]	validation_0-rmse:0.15250	validation_1-rmse:0.14062
# [422]	validation_0-rmse:0.15244	validation_1-rmse:0.14063
# [424]	validation_0-rmse:0.15239	validation_1-rmse:0.14064
# [426]	validation_0-rmse:0.15232	validation_1-rmse:0.14067
# [428]	validation_0-rmse:0.15228	validation_1-rmse:0.14065
# [430]	validation_0-rmse:0.15224	validation_1-rmse:0.14063
# [432]	validation_0-rmse:0.15221	validation_1-rmse:0.14063
# [434]	validation_0-rmse:0.15210	validation_1-rmse:0.14065
# [436]	validation_0-rmse:0.15202	validation_1-rmse:0.14065
# [438]	validation_0-rmse:0.15193	validation_1-rmse:0.14062
# [440]	validation_0-rmse:0.15188	validation_1-rmse:0.14059
# [442]	validation_0-rmse:0.15186	validation_1-rmse:0.14061
# [444]	validation_0-rmse:0.15180	validation_1-rmse:0.14062
# [446]	validation_0-rmse:0.15173	validation_1-rmse:0.14060
# [448]	validation_0-rmse:0.15165	validation_1-rmse:0.14059
# [450]	validation_0-rmse:0.15156	validation_1-rmse:0.14057
# [452]	validation_0-rmse:0.15147	validation_1-rmse:0.14054
# [454]	validation_0-rmse:0.15139	validation_1-rmse:0.14069
# [456]	validation_0-rmse:0.15134	validation_1-rmse:0.14069
# [458]	validation_0-rmse:0.15128	validation_1-rmse:0.14069
# [460]	validation_0-rmse:0.15123	validation_1-rmse:0.14069
# [462]	validation_0-rmse:0.15116	validation_1-rmse:0.14069
# [464]	validation_0-rmse:0.15107	validation_1-rmse:0.14071
# [466]	validation_0-rmse:0.15098	validation_1-rmse:0.14067
# [468]	validation_0-rmse:0.15090	validation_1-rmse:0.14066
# [470]	validation_0-rmse:0.15083	validation_1-rmse:0.14065
# [472]	validation_0-rmse:0.15078	validation_1-rmse:0.14065
# [474]	validation_0-rmse:0.15074	validation_1-rmse:0.14064
# [476]	validation_0-rmse:0.15066	validation_1-rmse:0.14058
# [478]	validation_0-rmse:0.15059	validation_1-rmse:0.14062
# [480]	validation_0-rmse:0.15056	validation_1-rmse:0.14061
# [482]	validation_0-rmse:0.15047	validation_1-rmse:0.14058
# [484]	validation_0-rmse:0.15041	validation_1-rmse:0.14059
# [486]	validation_0-rmse:0.15039	validation_1-rmse:0.14060
# [488]	validation_0-rmse:0.15034	validation_1-rmse:0.14063
# [490]	validation_0-rmse:0.15026	validation_1-rmse:0.14060
# [492]	validation_0-rmse:0.15024	validation_1-rmse:0.14061
# [494]	validation_0-rmse:0.15020	validation_1-rmse:0.14061
# [496]	validation_0-rmse:0.15015	validation_1-rmse:0.14062
# [498]	validation_0-rmse:0.15008	validation_1-rmse:0.14064
# [499]	validation_0-rmse:0.15006	validation_1-rmse:0.14064

# %% [markdown]
# ## Predictions Evaluation

# %%
train_predict = model.predict(X_train).reshape(-1, 1)
test_predict = model.predict(X_test).reshape(-1, 1)

train_predict_inv = target_scaler.inverse_transform(train_predict)
test_predict_inv = target_scaler.inverse_transform(test_predict)

y_train_inv = target_scaler.inverse_transform(y_train)
y_test_inv = target_scaler.inverse_transform(y_test)

print('Train Mean Absolute Error:', mean_absolute_error(y_train_inv, train_predict_inv))
print('Train Root Mean Squared Error:', np.sqrt(mean_squared_error(y_train_inv, train_predict_inv)))
print('Train R2 score:', r2_score(y_train_inv, train_predict_inv))

print('Test Mean Absolute Error:', mean_absolute_error(y_test_inv, test_predict_inv))
print('Test Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test_inv, test_predict_inv)))
print('Test R2 score:', r2_score(y_test_inv, test_predict_inv))
# Out:
# Train Mean Absolute Error: 0.06543057306206972
# Train Root Mean Squared Error: 0.16380172152170172
# Train R2 score: 0.9774819609607452
# Test Mean Absolute Error: 0.06596015333186109
# Test Root Mean Squared Error: 0.15352113846034884
# Test R2 score: 0.9707178550512007

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,5))
plt.plot(y_test, label='Actual')
plt.plot(test_predict, label='Predicted')
plt.title('XGBoost Prediction vs Actual')
plt.legend()
plt.show()

# %%
indice = 12000 #number of testing examples to use

limit = [x for x in range(indice)]
plt.figure(figsize=(20,6))

plt.plot(limit, y_test[:indice], label="actual", color='green')
plt.plot(limit, test_predict[:,0][:indice], '-', label="prediction", color='red')

plt.ylabel('Global_active_power')
plt.xlabel('Time step in minutes')
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# ## Conclusion:
#
# The model is predicting the electric power usage in a time-series bound way and is returning efficient results.
